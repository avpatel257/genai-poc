# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3.2")

result = llm.invoke("tell me joke about cats")

print(result)
# Out:
# content='Why did the cat join a band?\n\nBecause it wanted to be the purr-cussionist.' additional_kwargs={} response_metadata={'model': 'llama3.2', 'created_at': '2025-10-10T17:05:38.441596Z', 'done': True, 'done_reason': 'stop', 'total_duration': 373757291, 'load_duration': 57647833, 'prompt_eval_count': 30, 'prompt_eval_duration': 142077291, 'eval_count': 21, 'eval_duration': 173623459, 'model_name': 'llama3.2'} id='run--9582ec13-dee5-4552-9eb1-b7712b28cd93-0' usage_metadata={'input_tokens': 30, 'output_tokens': 21, 'total_tokens': 51}
